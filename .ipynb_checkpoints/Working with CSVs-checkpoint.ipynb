# %%
pwd
# Out:
# '/mnt/5040930D4092F944/Deepak/Python'

# %%
import csv

# %%
data = open('sample.csv')

# %%
data
# Out:
# <_io.TextIOWrapper name='sample.csv' mode='r' encoding='UTF-8'>

# %%
# If there is unicode decode error then we need to add encoding parameter
# data = open('sample.csv',encoding='....')

# %%
csv_data = csv.reader(data)

# %%
csv_data

# %%
csv_data = list(csv_data)

# %%
csv_data[:3]
# Out:
# [['8',
#   'l',
#   'h',
#   '1',
#   '9',
#   '6',
#   'x',
#   'r',
#   'a',
#   'i',
#   'n',
#   'y',
#   'h',
#   's',
#   'k',
#   'v',
#   '9'],
#  ['r',
#   'j',
#   't',
#   '2',
#   'c',
#   'm',
#   'g',
#   'a',
#   'd',
#   's',
#   's',
#   'c',
#   'v',
#   's',
#   '9',
#   '6',
#   '7'],
#  ['v',
#   '0',
#   't',
#   'i',
#   '8',
#   'w',
#   '0',
#   'm',
#   '0',
#   'x',
#   '0',
#   '8',
#   'd',
#   '9',
#   'm',
#   '7',
#   'h']]

# %%
data.close()

# %%
myfile = open('makeup.csv','w',newline='')

# %%
csv_writer = csv.writer(myfile,delimiter = ',')

# %%
csv_writer.writerow(['col1','col2','col3'])
# Out:
# 16

# %%
csv_writer.writerows([[1,3,5],[5,3,6],[6,7,3]])

# %%
myfile.close()

# %%
myfile = open('makeup.csv','a+',newline='')

# %%
csv_writer = csv.writer(myfile)

# %%
csv_writer.writerow([4,4,5])
# Out:
# 7

# %%
myfile.seek(0)
# Out:
# 0

# %%
csv_reader = csv.reader(myfile)

# %%
csv_data = list(csv_reader)

# %%
csv_data
# Out:
# [['col1', 'col2', 'col3'],
#  ['1', '3', '5'],
#  ['5', '3', '6'],
#  ['6', '7', '3'],
#  ['4', '4', '5']]

# %%
myfile.close()

# %%
myfile = open('sample.csv','r')

# %%
csv_reader = csv.reader(myfile)

# %%
csv_data = list(csv_reader)

# %%
csv_data
# Out:
# [['8',
#   'l',
#   'h',
#   '1',
#   '9',
#   '6',
#   'x',
#   'r',
#   'a',
#   'i',
#   'n',
#   'y',
#   'h',
#   's',
#   'k',
#   'v',
#   '9'],
#  ['r',
#   'j',
#   't',
#   '2',
#   'c',
#   'm',
#   'g',
#   'a',
#   'd',
#   's',
#   's',
#   'c',
#   'v',
#   's',
#   '9',
#   '6',
#   '7'],
#  ['v',
#   '0',
#   't',
#   'i',
#   '8',
#   'w',
#   '0',
#   'm',
#   '0',
#   'x',
#   '0',
#   '8',
#   'd',
#   '9',
#   'm',
#   '7',
#   'h'],
#  ['r',
#   'x',
#   'p',
#   '0',
#   's',
#   '/',
#   'y',
#   'd',
#   'g',
#   'k',
#   'u',
#   '7',
#   'j',
#   'y',
#   'h',
#   'd',
#   '.'],
#  ['y',
#   'n',
#   's',
#   'r',
#   '/',
#   'u',
#   '0',
#   'y',
#   'u',
#   'n',
#   '0',
#   'p',
#   '/',
#   '.',
#   'd',
#   'y',
#   '5'],
#  ['f',
#   'h',
#   ':',
#   'h',
#   'n',
#   '4',
#   'a',
#   'h',
#   '.',
#   'z',
#   '4',
#   '9',
#   'n',
#   'g',
#   'e',
#   'e',
#   'x'],
#  ['i',
#   '4',
#   '/',
#   'h',
#   'z',
#   '3',
#   '.',
#   'b',
# ...

# %%
link = []
for row in csv_data:
    link.append(row[2])

# %%
print(''.join(link))
# Out:
# https://drive.google.com/file/d/14oSxiKv35enpyyr81dDqEhkwnUONghPQ/

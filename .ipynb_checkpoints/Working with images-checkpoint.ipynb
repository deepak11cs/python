# %%
# !pip install Pillow

# %%
from PIL import Image

# %%
img = Image.open('image_link.PNG')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1226x777 at 0x7F28B6BD1F60>

# %%
img.size
# Out:
# (1226, 777)

# %%
new = img.crop((0,0,1000,670))

# %%
new
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x670 at 0x7F28B66AE5C0>

# %%
new = new.resize((500,335))

# %%
new
# Out:
# <PIL.Image.Image image mode=RGBA size=500x335 at 0x7F28B666E2B0>

# %%
img.paste(im=new,box=(0,0))

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1226x777 at 0x7F28B6BD1F60>

# %%
img.filename
# Out:
# 'image_link.PNG'

# %%
img.format_description
# Out:
# 'Portable network graphics'

# %%
img.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGBA size=1226x777 at 0x7F28B6646DA0>

# %%
new.putalpha(90)

# %%
new
# Out:
# <PIL.Image.Image image mode=RGBA size=500x335 at 0x7F28B666E2B0>

# %%
new.resize((500,335))
# Out:
# <PIL.Image.Image image mode=RGBA size=500x335 at 0x7F28A3460940>

# %%
img.paste(im=new,box=(670,0),mask=new)

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1226x777 at 0x7F28B6BD1F60>

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# This is markdown text, basically used for description about the code

# %%
print('Coding here is fun')
# Out:
# Coding here is fun

# %%
print('done with first notebook')
# Out:
# done with first notebook

# %%
from PIL import Image

# %%
img = Image.open('image_link.PNG')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1226x777 at 0x7F39443CC860>

# %%
img.size
# Out:
# (1226, 777)

# %%
cover = Image.open('cover_image.PNG')

# %%
cover
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1093x693 at 0x7F3936F3A5C0>

# %%
cover.size
# Out:
# (1093, 693)

# %%
img = img.resize((1093,693))

# %%
img.putalpha(70)

# %%
cover.paste(im=img,box=(0,0),mask=img)

# %%
cover
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1093x693 at 0x7F3936F3A5C0>

# %% [markdown]
# https://docs.google.com/document/d/1Zoa2NH44cAqm60R7HRYHoDzjXRLqz-89Fo4KBxzQ-Aw/edit

# %% [markdown]
# Tuples are ordered sequence of objects just like lists except that they are immutable.

# %%
mytuple = (1,3,5,5,2)

# %%
mytuple
# Out:
# (1, 3, 5, 5, 2)

# %%
mytuple[3]
# Out:
# 5

# %%
mytuple.count(5)
# Out:
# 2

# %%
mytuple.index(5)
# Out:
# 2

# %%
mytuple.index(2)
# Out:
# 4

# %%
mytuple.count(1)
# Out:
# 1
